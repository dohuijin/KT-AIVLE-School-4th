# %% [markdown]
# <a href="https://colab.research.google.com/github/dohuijin/KT-AIVLE-School-4th/blob/main/5_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5. 데이터 분석
# * 미션: 버스 노선 추가가 필요한 서울시 내 자치구 선정
# * 방법: 1부터 4까지의 ipynb 파일 순서대로 진행하며 데이터 불러오기 및 분석(EDA)을 수행하여 서울시 내 자치구별 정보를 도출하고<br> 이를 바탕으로 5. 데이터 분석에서 버스 노선 추가가 필요한 서울시 내 자치구를 선정<br><br>

# %% [markdown]
# #### [5.0.1] 데이터 합치기
# * 지금까지 1~4에서 준비한 데이터 파일
#     * 버스 정류장 데이터 - df_seoul_bus_station.csv
#     * 유동인구 데이터 - df_seoul_moving.csv
#     * 구별 등록 인구 데이터 - df_seoul_people.csv
#     * 구별 상권 데이터 - df_seoul_business.csv
# * 아래 제시되는 'standard' 데이터 프레임을 기준으로 활용하여, 지금까지 1~4에서 준비한 데이터를 각각 불러와서 합쳐 주세요.
# * 이후에는 이 합쳐진 데이터 프레임을 기반으로 미션을 수행하기 위한 분석을 진행합니다.

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 데이터 합치기 진행 시, 아래 제시되는 정보를 활용하세요.
standard = pd.DataFrame({'도착 시군구 코드': [11010, 11020, 11030, 11040, 11050, 11060, 11070, 11080, 11090, 11100, 11110, 11120, 11130, 11140, 11150, 11160, 11170, 11180, 11190, 11200, 11210, 11220, 11230, 11240, 11250],
                         '자치구' :['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서초구','강남구','송파구','강동구']})
standard
# Out:
#     도착 시군구 코드   자치구
# 0       11010   종로구
# 1       11020    중구
# 2       11030   용산구
# 3       11040   성동구
# 4       11050   광진구
# 5       11060  동대문구
# 6       11070   중랑구
# 7       11080   성북구
# 8       11090   강북구
# 9       11100   도봉구
# 10      11110   노원구
# 11      11120   은평구
# 12      11130  서대문구
# 13      11140   마포구
# 14      11150   양천구
# 15      11160   강서구
# 16      11170   구로구
# 17      11180   금천구
# 18      11190  영등포구
# 19      11200   동작구
# 20      11210   관악구
# 21      11220   서초구
# 22      11230   강남구
# 23      11240   송파구
# 24      11250   강동구

# %%
df_seoul_bus_station = pd.read_csv('/content/drive/MyDrive/미니프로젝트/1차_서울시 생활정보 기반 대중교통 수요 분석/데이터/df_seoul_bus_station.csv', index_col=0)
df_seoul_moving = pd.read_csv('/content/drive/MyDrive/미니프로젝트/1차_서울시 생활정보 기반 대중교통 수요 분석/데이터/df_seoul_moving.csv', index_col=0)
df_seoul_people = pd.read_csv('/content/drive/MyDrive/미니프로젝트/1차_서울시 생활정보 기반 대중교통 수요 분석/데이터/df_seoul_people.csv', index_col=0)
df_seoul_business = pd.read_csv('/content/drive/MyDrive/미니프로젝트/1차_서울시 생활정보 기반 대중교통 수요 분석/데이터//df_seoul_business.csv', index_col=0)

# %%
df_seoul_bus_station.head()
# Out:
#      버스 정류장 수  버스 노선 수   승차총승객수   하차총승객수     승차평균승객수     하차평균승객수
# 자치구
# 강남구       499       92  8030483  7569213  128.767927  121.371512
# 강동구       369       21  2890053  2830506   99.161194   97.118065
# 강북구       413       67  4825181  4671783  133.020373  128.791504
# 강서구       566       49  4681083  4652828   88.119480   87.587591
# 관악구       466       88  7655819  7792476  154.753674  157.516040

# %%
df_seoul_moving = pd.merge(df_seoul_moving, standard)
df_seoul_moving.head()
# Out:
#    도착 시군구 코드  구별 이동 시간 평균  구별 이동 인구 평균  구별 이동 시간 합   구별 이동 인구 합  자치구
# 0      11010    21.349599    44.235978     9356120  19385709.60  종로구
# 1      11020    21.012462    44.516072     9306020  19715322.61   중구
# 2      11030    21.364786    36.903883     8514380  14707082.87  용산구
# 3      11040    21.740324    42.685596     8887140  17449273.95  성동구
# 4      11050    22.474283    46.762548     8625540  17947278.99  광진구

# %%
df_seoul_people.head()
# Out:
#     자치구      총합   남자 총합   여자 총합  65세 이상 고령자
# 0    중구  131450   63869   67581       24742
# 1   용산구  236518  114571  121947       39461
# 2   성동구  291609  141662  149947       46896
# 3   광진구  353110  169525  183585       52604
# 4  동대문구  352592  172318  180274       62963

# %%
df_seoul_business.head()
# Out:
#     자치구 택시운송업 사업체수 택시운송업 종사자수 한식 일반 음식점업 사업체수 한식 일반 음식점업 종사자수  \
# 0   종로구        215        215           1,548           5,912
# 18   중구        230        235           1,588           6,414
# 34  용산구        416        523             857           2,987
# 51  성동구      1,200      2,527             956           2,785
# 69  광진구      1,119      1,744             963           2,861
#
#    용달 화물자동차 운송업 사업체수 용달 화물자동차 운송업 종사자수 부동산 중개 및 대리업 사업체수 부동산 중개 및 대리업 종사자수  \
# 0                618               646               549               889
# 18               300               333               576             1,152
# 34               455               466               791             1,214
# 51             1,072             1,161               801             1,453
# 69               968               985               871             1,313
#
#    두발미용업 사업체수  ... 커피전문점 사업체수 커피전문점 종사자수 남녀용 겉옷 및 셔츠 도매업 사업체수  \
# 0         261  ...        948      3,613                  400
# ...

# %%
df_seoul_bus_station.reset_index(inplace=True)
df_seoul_bus_station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   level_0   25 non-null     int64
#  1   index     25 non-null     int64
#  2   자치구       25 non-null     object
#  3   버스 정류장 수  25 non-null     int64
#  4   버스 노선 수   25 non-null     int64
#  5   승차총승객수    25 non-null     int64
#  6   하차총승객수    25 non-null     int64
#  7   승차평균승객수   25 non-null     float64
#  8   하차평균승객수   25 non-null     float64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 1.9+ KB

# %%
df_seoul_bus_station.head()
# Out:
#    level_0  index  자치구  버스 정류장 수  버스 노선 수   승차총승객수   하차총승객수     승차평균승객수  \
# 0        0      0  강남구       499       92  8030483  7569213  128.767927
# 1        1      1  강동구       369       21  2890053  2830506   99.161194
# 2        2      2  강북구       413       67  4825181  4671783  133.020373
# 3        3      3  강서구       566       49  4681083  4652828   88.119480
# 4        4      4  관악구       466       88  7655819  7792476  154.753674
#
#       하차평균승객수
# 0  121.371512
# 1   97.118065
# 2  128.791504
# 3   87.587591
# 4  157.516040

# %%
df_seoul_bus_station.drop(['level_0', 'index'], axis=1, inplace=True)
df_seoul_bus_station.head()
# Out:
#    자치구  버스 정류장 수  버스 노선 수   승차총승객수   하차총승객수     승차평균승객수     하차평균승객수
# 0  강남구       499       92  8030483  7569213  128.767927  121.371512
# 1  강동구       369       21  2890053  2830506   99.161194   97.118065
# 2  강북구       413       67  4825181  4671783  133.020373  128.791504
# 3  강서구       566       49  4681083  4652828   88.119480   87.587591
# 4  관악구       466       88  7655819  7792476  154.753674  157.516040

# %%
a = df_seoul_bus_station.set_index(['자치구'])
b = df_seoul_business.set_index(['자치구'])
c = df_seoul_moving.set_index(['자치구'])
d = df_seoul_people.iloc[1:].set_index(['자치구'])

df_all = pd.concat([a,b,c,d], axis=1).reset_index().rename(columns = {'index' : '자치구'})

# %%
df_all.head()
# Out:
#    자치구  버스 정류장 수  버스 노선 수   승차총승객수   하차총승객수     승차평균승객수     하차평균승객수  \
# 0  강남구       499       92  8030483  7569213  128.767927  121.371512
# 1  강동구       369       21  2890053  2830506   99.161194   97.118065
# 2  강북구       413       67  4825181  4671783  133.020373  128.791504
# 3  강서구       566       49  4681083  4652828   88.119480   87.587591
# 4  관악구       466       88  7655819  7792476  154.753674  157.516040
#
#   택시운송업 사업체수 택시운송업 종사자수 한식 일반 음식점업 사업체수  ... 한식 육류요리 전문점 종사자수 도착 시군구 코드  \
# 0      1,796      2,517           2,415  ...            5,008     11230
# 1      3,295      4,980           1,101  ...            1,459     11250
# 2      1,713      2,589             965  ...            1,176     11090
# 3      3,735      6,922           1,325  ...            2,274     11160
# 4      1,286      2,027           1,226  ...            1,628     11210
#
#   구별 이동 시간 평균 구별 이동 인구 평균 구별 이동 시간 합   구별 이동 인구 합        총합     남자 총합  \
# ...

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   자치구                   25 non-null     object
#  1   버스 정류장 수              25 non-null     int64
#  2   버스 노선 수               25 non-null     int64
#  3   승차총승객수                25 non-null     int64
#  4   하차총승객수                25 non-null     int64
#  5   승차평균승객수               25 non-null     float64
#  6   하차평균승객수               25 non-null     float64
#  7   택시운송업 사업체수            25 non-null     object
#  8   택시운송업 종사자수            25 non-null     object
#  9   한식 일반 음식점업 사업체수       25 non-null     object
#  10  한식 일반 음식점업 종사자수       25 non-null     object
#  11  용달 화물자동차 운송업 사업체수     25 non-null     object
#  12  용달 화물자동차 운송업 종사자수     25 non-null     object
#  13  부동산 중개 및 대리업 사업체수     25 non-null     object
#  14  부동산 중개 및 대리업 종사자수     25 non-null     object
# ...

# %%
df_all.describe()
# Out:
#          버스 정류장 수     버스 노선 수        승차총승객수        하차총승객수     승차평균승객수  \
# count   25.000000   25.000000  2.500000e+01  2.500000e+01   25.000000
# mean   424.600000   73.440000  4.912037e+06  4.800701e+06  115.718291
# std    106.279506   24.236818  1.421263e+06  1.400538e+06   17.080840
# min    178.000000   21.000000  2.749448e+06  2.746738e+06   87.403863
# 25%    349.000000   56.000000  3.792541e+06  3.740923e+06  103.907639
# 50%    435.000000   71.000000  4.942197e+06  4.730992e+06  119.235615
# 75%    499.000000   97.000000  5.641742e+06  5.603488e+06  126.687777
# max    602.000000  107.000000  8.030483e+06  7.792476e+06  154.753674
#
#           하차평균승객수  한식 육류요리 전문점 사업체수     도착 시군구 코드  구별 이동 시간 평균  구별 이동 인구 평균  \
# count   25.000000         25.000000     25.000000    25.000000    25.000000
# mean   113.031529        444.360000  11130.000000    22.997543    49.935234
# std     16.865744        130.938561     73.598007     1.357258    13.941384
# ...

# %%
df_all.to_csv('/content/drive/MyDrive/미니프로젝트/1차_서울시 생활정보 기반 대중교통 수요 분석/seoul_data.csv', index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화 한글폰트 설정
# 맑은 고딕

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding",
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# scipy
import scipy.stats as spst

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x='자치구', y='버스 노선 수',data=df_all)
sns.lineplot(x='자치구', y='버스 정류장 수',data=df_all)
# Out:
# <Axes: xlabel='자치구', ylabel='버스 노선 수'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   func(*args, **kwargs)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
#그래프 크기
plt.figure(figsize=(12,8))

#그래프 그리기
plt.plot(df_all['자치구'],df_all['승차총승객수'])

plt.plot(df_all['자치구'],df_all['하차총승객수'])

#꾸미기
plt.xlabel('Date')
plt.title('Airquality')
plt.legend(loc='upper right')
plt.grid()

#마무리
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
df_seoul_people.sort_values(by='총합', ascending=False)
# Out:
#      자치구      총합   남자 총합   여자 총합  65세 이상 고령자
# 22   송파구  668261  321963  346298       99854
# 14   강서구  578426  277797  300629       93924
# 21   강남구  537338  257096  280242       79575
# 9    노원구  514445  247417  267028       89426
# 19   관악구  500336  250450  249886       80686
# 10   은평구  476013  227172  248841       88418
# 23   강동구  465097  227891  237206       75477
# 13   양천구  449378  219882  229496       69953
# 6    성북구  442680  212277  230403       75719
# 15   구로구  419984  208027  211957       73864
# 20   서초구  413677  197665  216012       61404
# 17  영등포구  400241  198080  202161       63547
# 18   동작구  394649  190377  204272       67470
# 5    중랑구  393600  193623  199977       72851
# 12   마포구  378629  176886  201743       55168
# 3    광진구  353110  169525  183585       52604
# 4   동대문구  352592  172318  180274       62963
# 8    도봉구  318100  154440  163660       65122
# 11  서대문구  317075  149805  167270       55012
# 7    강북구  300824  145934  154890       64961
# ...

# %%
df_seoul_people.sort_values(by='65세 이상 고령자', ascending=False)
# Out:
#      자치구      총합   남자 총합   여자 총합  65세 이상 고령자
# 22   송파구  668261  321963  346298       99854
# 14   강서구  578426  277797  300629       93924
# 9    노원구  514445  247417  267028       89426
# 10   은평구  476013  227172  248841       88418
# 19   관악구  500336  250450  249886       80686
# 21   강남구  537338  257096  280242       79575
# 6    성북구  442680  212277  230403       75719
# 23   강동구  465097  227891  237206       75477
# 15   구로구  419984  208027  211957       73864
# 5    중랑구  393600  193623  199977       72851
# 13   양천구  449378  219882  229496       69953
# 18   동작구  394649  190377  204272       67470
# 8    도봉구  318100  154440  163660       65122
# 7    강북구  300824  145934  154890       64961
# 17  영등포구  400241  198080  202161       63547
# 4   동대문구  352592  172318  180274       62963
# 20   서초구  413677  197665  216012       61404
# 12   마포구  378629  176886  201743       55168
# 11  서대문구  317075  149805  167270       55012
# 3    광진구  353110  169525  183585       52604
# ...

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 47448 (\N{HANGUL SYLLABLE RYU}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.draw()
# ...
