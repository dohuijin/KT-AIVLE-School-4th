# %% [markdown]
# <a href="https://colab.research.google.com/github/dohuijin/KT-AIVLE-School-4th/blob/main/4_%EA%B5%AC%EB%B3%84_%EC%97%85%EC%A2%85_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4. 구 별 업종 분석
# ### 서울시 내 각 구 별로 등록업종을 분석

# %% [markdown]
# ## 데이터 안내
#
# [데이터 파일명]
# * 4. seoul_people.csv
#
# [데이터 정보]
# * 서울 시 구별 등록 업종 상위 10개 데이터
#     * 택시운송업
#     * 한식일반음식점업
#     * 용달 화물자동차 운송업
#     * 부동산 중개 및 대리업
#     * 두발미용업
#     * 커피전문점
#     * 남녀용 겉옷 및 셔츠 도매업
#     * 기타주점업
#     * 일반 교과 학원
#     * 한식 육류요리 전문점
#
# [데이터 컬럼 정보]
# * 다수 업종 상위 1~10

# %% [markdown]
# #### [4.1.1] 데이터 로딩

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
seoul_business = pd.read_csv('/content/drive/MyDrive/미니프로젝트/1차_서울시 생활정보 기반 대중교통 수요 분석/데이터/4. business_type.csv')

# %%
seoul_business.shape
# Out:
# (451, 22)

# %% [markdown]
# # 4.2.기본 정보 확인 및 클렌징
#
# + 데이터 클렌징 : 결측치, 이상치 등을 제거하여 데이터 분석 결과가 왜곡 되는 문제를 방지하기 위한 정제 과정

# %% [markdown]
# #### [4.2.1] 기본 정보 확인하기

# %%
seoul_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   자치구           451 non-null    object
#  1   동             451 non-null    object
#  2   다수업종 상위10     451 non-null    object
#  3   다수업종 상위10.1   451 non-null    object
#  4   다수업종 상위10.2   451 non-null    object
#  5   다수업종 상위10.3   451 non-null    object
#  6   다수업종 상위10.4   451 non-null    object
#  7   다수업종 상위10.5   451 non-null    object
#  8   다수업종 상위10.6   451 non-null    object
#  9   다수업종 상위10.7   451 non-null    object
#  10  다수업종 상위10.8   451 non-null    object
#  11  다수업종 상위10.9   451 non-null    object
#  12  다수업종 상위10.10  451 non-null    object
#  13  다수업종 상위10.11  451 non-null    object
#  14  다수업종 상위10.12  451 non-null    object
#  15  다수업종 상위10.13  451 non-null    object
#  16  다수업종 상위10.14  451 non-null    object
#  17  다수업종 상위10.15  451 non-null    object
# ...

# %%
seoul_business.head()
# Out:
#    자치구    동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3   다수업종 상위10.4  \
# 0  자치구    동     택시운송업       택시운송업  한식 일반 음식점업  한식 일반 음식점업  용달 화물자동차 운송업
# 1  자치구    동      사업체수        종사자수        사업체수        종사자수          사업체수
# 2   합계   합계    47,176      76,701      29,225     100,183        28,494
# 3  종로구   소계       215         215       1,548       5,912           618
# 4  종로구  사직동         7           7         230         982            12
#
#     다수업종 상위10.5   다수업종 상위10.6   다수업종 상위10.7  ... 다수업종 상위10.10 다수업종 상위10.11  \
# 0  용달 화물자동차 운송업  부동산 중개 및 대리업  부동산 중개 및 대리업  ...        커피전문점        커피전문점
# 1          종사자수          사업체수          종사자수  ...         사업체수         종사자수
# 2        29,356        24,013        42,636  ...       16,255       57,322
# 3           646           549           889  ...          948        3,613
# 4            12            57            96  ...          124          525
#
#       다수업종 상위10.12     다수업종 상위10.13 다수업종 상위10.14 다수업종 상위10.15 다수업종 상위10.16  \
# ...

# %%
print(seoul_business.loc[0])
print(seoul_business.loc[1])
# Out:
# 자치구                         자치구
# 동                             동
# 다수업종 상위10                 택시운송업
# 다수업종 상위10.1               택시운송업
# 다수업종 상위10.2          한식 일반 음식점업
# 다수업종 상위10.3          한식 일반 음식점업
# 다수업종 상위10.4        용달 화물자동차 운송업
# 다수업종 상위10.5        용달 화물자동차 운송업
# 다수업종 상위10.6        부동산 중개 및 대리업
# 다수업종 상위10.7        부동산 중개 및 대리업
# 다수업종 상위10.8               두발미용업
# 다수업종 상위10.9               두발미용업
# 다수업종 상위10.10              커피전문점
# 다수업종 상위10.11              커피전문점
# 다수업종 상위10.12    남녀용 겉옷 및 셔츠 도매업
# 다수업종 상위10.13    남녀용 겉옷 및 셔츠 도매업
# 다수업종 상위10.14              기타주점업
# 다수업종 상위10.15              기타주점업
# 다수업종 상위10.16           일반 교과 학원
# 다수업종 상위10.17           일반 교과 학원
# 다수업종 상위10.18        한식 육류요리 전문점
# 다수업종 상위10.19        한식 육류요리 전문점
# Name: 0, dtype: object
# 자치구              자치구
# 동                  동
# 다수업종 상위10       사업체수
# 다수업종 상위10.1     종사자수
# 다수업종 상위10.2     사업체수
# 다수업종 상위10.3     종사자수
# 다수업종 상위10.4     사업체수
# 다수업종 상위10.5     종사자수
# 다수업종 상위10.6     사업체수
# ...

# %% [markdown]
# #### [4.2.2] 원하는 데이터 형태로 저장하기
#
# * head, tail 등을 살펴본 결과를 토대로 header 값을 적절히 지정하여 데이터를 다시 불러오고 필요한 컬럼만 저장

# %%
#read_csv 재실행. 단, header값을 적절히 지정
seoul_business = pd.read_csv('/content/drive/MyDrive/미니프로젝트/1차_서울시 생활정보 기반 대중교통 수요 분석/데이터/4. business_type.csv', header=3)

# %%
seoul_business.head()
# Out:
#     합계 합계.1 47,176 76,701 29,225 100,183 28,494 29,356 24,013 42,636  ...  \
# 0  종로구   소계    215    215  1,548   5,912    618    646    549    889  ...
# 1  종로구  사직동      7      7    230     982     12     12     57     96  ...
# 2  종로구  삼청동      5      5     42     145      4      4      9     10  ...
# 3  종로구  부암동     22     22     26     100      9      9     17     26  ...
# 4  종로구  평창동     10     10     31     116     11     11     33     52  ...
#
#   16,255 57,322 13,388 51,116 13,339 31,371 11,911 50,773 11,109 44,653
# 0    948  3,613    400    962    537  1,413    110    382    437  1,982
# 1    124    525      2     18     74    177      9     34     45    220
# 2     66    243      2      3      3      8      -      -      7     33
# 3     24     62      3      6      7     23     16     59      3     15
# 4     19     62      2      4     26     54     25     71     10    103
#
# [5 rows x 22 columns]

# %%
seoul_business.columns = ['자치구', '동',
                          '택시운송업 사업체수', '택시운송업 종사자수', '한식 일반 음식점업 사업체수', '한식 일반 음식점업 종사자수',
                          '용달 화물자동차 운송업 사업체수', '용달 화물자동차 운송업 종사자수',
                          '부동산 중개 및 대리업 사업체수', '부동산 중개 및 대리업 종사자수',
                          '두발미용업 사업체수', '두발미용업 종사자수', '커피전문점 사업체수', '커피전문점 종사자수',
                          '남녀용 겉옷 및 셔츠 도매업 사업체수', '남녀용 겉옷 및 셔츠 도매업 종사자수',
                          '기타주점업 사업체수', '기타주점업 종사자수', '일반 교과 학원 사업체수', '일반 교과 학원 종사자수',
                          '한식 육류요리 전문점 사업체수', '한식 육류요리 전문점 종사자수']

# %%
seoul_business.head()
# Out:
#    자치구    동 택시운송업 사업체수 택시운송업 종사자수 한식 일반 음식점업 사업체수 한식 일반 음식점업 종사자수  \
# 0  종로구   소계        215        215           1,548           5,912
# 1  종로구  사직동          7          7             230             982
# 2  종로구  삼청동          5          5              42             145
# 3  종로구  부암동         22         22              26             100
# 4  종로구  평창동         10         10              31             116
#
#   용달 화물자동차 운송업 사업체수 용달 화물자동차 운송업 종사자수 부동산 중개 및 대리업 사업체수 부동산 중개 및 대리업 종사자수  \
# 0               618               646               549               889
# 1                12                12                57                96
# 2                 4                 4                 9                10
# 3                 9                 9                17                26
# 4                11                11                33                52
#
#    ... 커피전문점 사업체수 커피전문점 종사자수 남녀용 겉옷 및 셔츠 도매업 사업체수 남녀용 겉옷 및 셔츠 도매업 종사자수  \
# ...

# %%
seoul_business['동'].value_counts()
# Out:
# 소계      25
# 신사동      2
# 독산2동     1
# 양평1동     1
# 당산2동     1
#         ..
# 미아동      1
# 삼양동      1
# 수유3동     1
# 수유2동     1
# 길동       1
# Name: 동, Length: 423, dtype: int64

# %%
seoul_business.head()
# Out:
#    자치구    동 택시운송업 사업체수 택시운송업 종사자수 한식 일반 음식점업 사업체수 한식 일반 음식점업 종사자수  \
# 0  종로구   소계        215        215           1,548           5,912
# 1  종로구  사직동          7          7             230             982
# 2  종로구  삼청동          5          5              42             145
# 3  종로구  부암동         22         22              26             100
# 4  종로구  평창동         10         10              31             116
#
#   용달 화물자동차 운송업 사업체수 용달 화물자동차 운송업 종사자수 부동산 중개 및 대리업 사업체수 부동산 중개 및 대리업 종사자수  \
# 0               618               646               549               889
# 1                12                12                57                96
# 2                 4                 4                 9                10
# 3                 9                 9                17                26
# 4                11                11                33                52
#
#    ... 커피전문점 사업체수 커피전문점 종사자수 남녀용 겉옷 및 셔츠 도매업 사업체수 남녀용 겉옷 및 셔츠 도매업 종사자수  \
# ...

# %%
# 동 컬럼의 값이 소계인 항목들만 골라내 보겠습니다.
# 위와 같이 동 컬럼의 소계를 구하면 자치구 별 값이 되므로 이후에 동 컬럼은 삭제, 결과적으로 자치구 별 값을 얻게 된다.
seoul_business.drop('동', axis=1, inplace=True)
seoul_business
# Out:
#       자치구 택시운송업 사업체수 택시운송업 종사자수 한식 일반 음식점업 사업체수 한식 일반 음식점업 종사자수  \
# 0     종로구        215        215           1,548           5,912
# 18     중구        230        235           1,588           6,414
# 34    용산구        416        523             857           2,987
# 51    성동구      1,200      2,527             956           2,785
# 69    광진구      1,119      1,744             963           2,861
# 85   동대문구      1,546      2,093           1,236           3,566
# 100   중랑구      3,634      6,262             991           2,479
# 117   성북구      1,835      2,643             973           2,822
# 138   강북구      1,713      2,589             965           2,663
# 152   도봉구      2,993      5,783             672           2,009
# 167   노원구      4,114      6,074             866           2,650
# 187   은평구      3,108      4,430             881           2,585
# 204  서대문구      1,747      2,677             863           2,694
# 219   마포구      1,165      1,838           1,411           4,705
# ...

# %%
seoul_business.to_csv('/content/drive/MyDrive/미니프로젝트/1차_서울시 생활정보 기반 대중교통 수요 분석/데이터/df_seoul_business.csv')
